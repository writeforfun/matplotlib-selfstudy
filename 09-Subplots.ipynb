# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
plt.style.use('seaborn')

# %%
data = pd.read_csv('09-Subplots.csv')

# %%
data.head()
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
data.describe()
# Out:
#              Age       All_Devs         Python     JavaScript
# count  38.000000      38.000000      38.000000      38.000000
# mean   36.500000   69257.078947   75754.210526   69707.921053
# std    11.113055   28739.996679   30104.281467   28899.282262
# min    18.000000   16500.000000   17100.000000   16446.000000
# 25%    27.250000   47394.000000   54709.250000   47440.500000
# 50%    36.500000   77616.000000   84016.000000   78754.000000
# 75%    45.750000   91653.250000   99810.000000   91660.000000
# max    55.000000  108923.000000  122870.000000  108000.000000

# %%
ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']

# %% [markdown]
# # Plot by **plt**

# %%
plt.plot(ages, py_salaries, label='Python')
plt.plot(ages, js_salaries, label='JavaScript')
plt.plot(ages, dev_salaries, color='#444444',
        linestyle='--', label='All Devs')

plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

plt.show()

# %% [markdown]
# #  plt是直接用，沒有給他一個定義
#
# 例如: **plt = Plot()** 這種格式 (當然實際上不是這樣定義)

# %% [markdown]
# # 用subplots() 畫圖

# %%
fig, ax = plt.subplots() #ax = plt

ax.plot(ages, py_salaries, label='Python')
ax.plot(ages, js_salaries, label='JavaScript')
ax.plot(ages, dev_salaries, color='#444444',
        linestyle='--', label='All Devs')

ax.legend()

# plt.title('Median Salary (USD) by Age')
ax.set_title('Median Salary (USD) by Age')

# plt.xlabel('Ages')
ax.set_xlabel('Ages')

# plt.ylabel('Median Salary (USD)')
ax.set_ylabel('Median Salary (USD)')

#remain plt
plt.tight_layout()
plt.show()

# %%
fig = plt.figure()
# ax = plt.subplot(111)
ax = plt.subplot()

ax.plot(ages, py_salaries, label='Python')
ax.plot(ages, js_salaries, label='JavaScript')
ax.plot(ages, dev_salaries, color='#444444',
        linestyle='--', label='All Devs')

ax.legend()

# plt.title('Median Salary (USD) by Age')
ax.set_title('Median Salary (USD) by Age')

# plt.xlabel('Ages')
ax.set_xlabel('Ages')

# plt.ylabel('Median Salary (USD)')
ax.set_ylabel('Median Salary (USD)')

#remain plt
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
print(ax)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
print(ax)
# Out:
# [<matplotlib.axes._subplots.AxesSubplot object at 0x118e5c710>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x118cce4d0>]

# %%
fig, ax = plt.subplots(nrows=2, ncols=1)
print(ax)
# Out:
# [<matplotlib.axes._subplots.AxesSubplot object at 0x118b3d810>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x1189d3910>]

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
print(ax)
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x118946dd0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x118b2c290>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x118f2e890>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x105bdc0d0>]]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)
print(ax1)
print(ax2)
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)

ax1.plot(ages, dev_salaries, color='#444444',
        linestyle='--', label='All Devs')

ax2.plot(ages, py_salaries, label='Python')
ax2.plot(ages, js_salaries, label='JavaScript')


ax1.legend()
ax1.set_title('Median Salary (USD) by Age')
ax1.set_xlabel('Ages')
ax1.set_ylabel('Median Salary (USD)')

ax2.legend()
ax2.set_title('Median Salary (USD) by Age')
ax2.set_xlabel('Ages')
ax2.set_ylabel('Median Salary (USD)')

#remain plt
plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)

ax1.plot(ages, dev_salaries, color='#444444',
        linestyle='--', label='All Devs')

ax2.plot(ages, py_salaries, label='Python')
ax2.plot(ages, js_salaries, label='JavaScript')


ax1.legend()
ax1.set_title('Median Salary (USD) by Age')
ax1.set_ylabel('Median Salary (USD)')

ax2.legend()
ax2.set_xlabel('Ages')
ax2.set_ylabel('Median Salary (USD)')

#remain plt
plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=True)

ax1.plot(ages, dev_salaries, color='#444444',
        linestyle='--', label='All Devs')

ax2.plot(ages, py_salaries, label='Python')
ax2.plot(ages, js_salaries, label='JavaScript')


ax1.legend()
ax1.set_title('Median Salary (USD) by Age')
ax1.set_ylabel('Median Salary (USD)')

ax2.legend()
ax2.set_xlabel('Ages')
ax2.set_ylabel('Median Salary (USD)')

#remain plt
plt.tight_layout()
plt.show()

# %% [markdown]
# # 把兩張圖分別畫在不一樣的fig上

# %%
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()

ax1.plot(ages, dev_salaries, color='#444444',
        linestyle='--', label='All Devs')

ax2.plot(ages, py_salaries, label='Python')
ax2.plot(ages, js_salaries, label='JavaScript')


ax1.legend()
ax1.set_title('Median Salary (USD) by Age')
ax1.set_ylabel('Median Salary (USD)')

ax2.legend()
ax2.set_xlabel('Ages')
ax2.set_ylabel('Median Salary (USD)')

#remain plt
plt.tight_layout()
plt.show()

# %%
fig1.savefig('09-fig1.png')
fig2.savefig('09-fig2.png')
